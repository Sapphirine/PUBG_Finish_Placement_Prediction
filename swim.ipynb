# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings("ignore")
train = pd.read_csv('train_V2.csv')

# %%
print("The average person swims for {:.1f}m, 99% of people have swimemd {}m or less, while the olympic champion swimmed for {}m.".format(train['swimDistance'].mean(), train['swimDistance'].quantile(0.99), train['swimDistance'].max()))
# Out:
# The average person swims for 4.5m, 99% of people have swimemd 123.0m or less, while the olympic champion swimmed for 3823.0m.

# %%
data = train.copy()
plt.figure(figsize=(15,10))
plt.title("Fig of Swim Distance",fontsize=15)
sns.distplot(data['swimDistance'],color="LightSkyBlue")
plt.show()
plt.figure(figsize=(15,10))
plt.title("Fig of Swim Distance",fontsize=15)
sns.distplot(data['swimDistance'],hist=False,color="LightSkyBlue")
plt.show()
plt.figure(figsize=(15,10))
plt.title("Fig of Swim Distance",fontsize=15)
sns.distplot(data['swimDistance'],kde=False,color="LightSkyBlue")
plt.show()

# %%
sns.jointplot(x="winPlacePerc", y="swimDistance", data=train, ratio=3, color="LightSkyBlue",kind='reg')
plt.show()

# %%
data = train.copy()

data['swimDistance'] = pd.cut(data['swimDistance'], [-1, 0, 10, 50, 100,5286], labels=['No Swim','1~10m', '10~50m','50~100m', 'Higher than 100m'])

plt.figure(figsize=(15,8))
sns.boxplot(x="swimDistance", y="winPlacePerc", data=data,palette="pastel")
plt.show()
